# %% [markdown]
# # 8장. 텍스트빈도분석 - 2) 한글 단어 분석

# %%
# !pip install KoNLPy
# Out:
# Requirement already satisfied: KoNLPy in /Users/hoho/opt/anaconda3/lib/python3.9/site-packages (0.6.0)
# Requirement already satisfied: numpy>=1.6 in /Users/hoho/opt/anaconda3/lib/python3.9/site-packages (from KoNLPy) (1.21.5)
# Requirement already satisfied: lxml>=4.1.0 in /Users/hoho/opt/anaconda3/lib/python3.9/site-packages (from KoNLPy) (4.8.0)
# Requirement already satisfied: JPype1>=0.7.0 in /Users/hoho/opt/anaconda3/lib/python3.9/site-packages (from KoNLPy) (1.3.0)

# %% [markdown]
# ## 한글 단어 분석을 위한 패키지 준비

# %%
import pandas as pd
import json
import re
import glob

from konlpy.tag import Okt

from collections import Counter

import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
from wordcloud import WordCloud
import re

# %% [markdown]
# # 1. 데이터 준비

# %%
# 관련 데이터 (엑셀파일) 불러오기
all_files = glob.glob('./myCabinetExcelKoData*.xls')

all_files
# Out:
# ['./myCabinetExcelKoData (7).xls',
#  './myCabinetExcelKoData (6).xls',
#  './myCabinetExcelKoData (5).xls',
#  './myCabinetExcelKoData (9).xls',
#  './myCabinetExcelKoData (8).xls']

# %%
all_files_data = [] #저장할 리스트 

for file in all_files:
    data_frame = pd.read_excel(file)
    all_files_data.append(data_frame)

all_files_data[0] #출력하여 내용 확인
# Out:
#     Unnamed: 0  번호                                                 제목  \
# 0          NaN   1  「Parametric power Transformer」의 作動特性에 관한 硏究[Ⅰ]...
# 1          NaN   2  무인 감시 Transformer = Visual Surveillance Transf...
# 2          NaN   3  Temporal Fusion Transformers와 심층 학습 방법을사용한 다층 ...
# 3          NaN   4  GITr(Gas Insulated Transformer)내부에 발생되는 PD 신호의...
# 4          NaN   5  GITr(Gas Insulated Transformer)내부에 발생되는 PD 신호의...
# ..         ...  ..                                                ...
# 94         NaN  95  Rogowski Coil과 Current Transformer의 직렬 아크 사고 측...
# 95         NaN  96  PDDL to LTL Description Translation for Collec...
# 96         NaN  97          方形波 pulse 入力에 對한 Transformer의 應答特性에 關한 硏究
# 97         NaN  98  CALCULATION OF INDUCTANCES OF TRANSFORMER EQUI...
# 98         NaN  99                  흡수식 히트펌프(Heat Transformer) 보수와 운전
#
#                       저자          출판사   출판일
# 0                    張正秀     慶北工業專門大學  1983
# 1                    최경훈  제어·로봇·시스템학회  2021
# 2                    김인경     한국정보처리학회  2022
# 3                    정승용       대한전기학회  2006
# 4   鄭承庸(Seung-yong Jung)       대한전기학회  2006
# ..                   ...          ...   ...
# 94      조찬기(Chan-Gi Cho)  한국조명·전기설비학회  2020
# 95            J. Y. Moon    제어로봇시스템학회  2020
# 96                   鄭元一     大田工業專門學校  1977
# 97          Chen Dongjun       전력전자학회  1998
# 98                   류진상      대한설비공학회  1993
#
# [99 rows x 6 columns]

# %%
# 데이터 파일 이어붙이기
all_files_data_concat = pd.concat(all_files_data, axis=0, ignore_index=True)

all_files_data_concat #출력하여 내용 확인
# Out:
#      Unnamed: 0   번호                                                 제목  \
# 0           NaN    1  「Parametric power Transformer」의 作動特性에 관한 硏究[Ⅰ]...
# 1           NaN    2  무인 감시 Transformer = Visual Surveillance Transf...
# 2           NaN    3  Temporal Fusion Transformers와 심층 학습 방법을사용한 다층 ...
# 3           NaN    4  GITr(Gas Insulated Transformer)내부에 발생되는 PD 신호의...
# 4           NaN    5  GITr(Gas Insulated Transformer)내부에 발생되는 PD 신호의...
# ..          ...  ...                                                ...
# 494         NaN   96  지하철 변전실용 진공주형형 몰드변압기의 난연성 확인에 관한 연구 = A Study ...
# 495         NaN   97  임피던스 변환회로의 신호 전달특성(S<sub>21</sub>) 측정 방법 = Mea...
# 496         NaN   98  전력용 변압기 초음파 측정시스템 적용 = Application of the Ultr...
# 497         NaN   99  소형화 및 슬림형에 적합한 평면 플라이백 변압기의최적 설계에 관한 연구 = A St...
# 498         NaN  100  전력용 변압기 온라인 유중가스 진단기준치 및 알고리즘에 관한 연구 = Study o...
#
#                        저자          출판사   출판일
# 0                     張正秀     慶北工業專門大學  1983
# 1                     최경훈  제어·로봇·시스템학회  2021
# 2                     김인경     한국정보처리학회  2022
# 3                     정승용       대한전기학회  2006
# 4    鄭承庸(Seung-yong Jung)       대한전기학회  2006
# ..                    ...          ...   ...
# 494                   정용기   한국조명전기설비학회  1998
# 495                   박웅희     한국정보통신학회  2019
# 496                   권동진       대한전기학회  2005
# 497                   나혜중     한국전기전자학회  2020
# 498                   진상범       대한전기학회  2005
#
# [499 rows x 6 columns]

# %%
# 제목 추출
all_title = all_files_data_concat['제목']

all_str = ''
# 논문 제목 1개마다 진행
for title in all_title:
    # 한글과 공백을 제외한 문자 제거
    title = re.sub('[^ㄱ-힗 ]+', '', title)
    # 복수의 공백 제거
    title = re.sub(' +', ' ', title)
    all_str = all_str + title
    
all_str
# Out:
# ' 의 作動特性에 관한 硏究 무인 감시  와 심층 학습 방법을사용한 다층 수평 시계열 데이터 분석  내부에 발생되는 신호의 패턴분석을 위한 와 적용결과 비교  내부에 발생되는 신호의 패턴분석을 위한 와 적용결과 비교  출력단을 로 통합 설계한 고효율 용 전원시스템       기반의 번역문 사후 교정 원시문과 기계번역문 간 효과적 관계모델링을 통한 기반 번역문 자동 사후 교정  를 응용한 전류형 구동에 관한 연구  를 갖는 의 구동회로  를 이용한 고온 초전도 케이블의 층간 전류 등분배 방안  와 을 활용한 전이학습 효과 검증 연구 법률상담데이터 분류문제 적용  를 이용한 고온초전도 케이블의 층간 전류 등분배 방안  를 이용한 계통 혼잡처리 방안  의 동작해석  용 개발  의 노이즈 억제성능 분석  용 개발 사례 다중 인코더 기반 번역문 자동 사후 교정 모델의 디코더 구조 연구  를 위한 양방향 컨버터 최적 설계  의 特性에 關한 實驗的 考察 전철용 고주파 대전력 비정질 개발  내부에 발생되는 신호의 패턴분석을 위한 와 적용 결과 비교  의 다중권선 전류 불균형 현상 분석 출력 를 없앤 계통 혼잡처리를 위한 의 최적 위치 선정 권선구조에 따른 해석 여자전압의 파형에 따른 의 특성 초고압 의 장기 과전압 시험에 관한 연구 광원에 따른 광 의 출력특성 연구  에서의 측정 기술 연구  출력단을 로 통합 설계한 고효율 용 전원시스템와 딥러닝을 이용한 지수 변동성 추정 을 위한 기반 자세 추정 기법 네트워크를 이용한 음성신호 변환     기반 번역문 사후 교정 위협 탐지 및 교통량 예측을 위한 장기 시계열 데이터에서의 와 모델 성능 비교 를 이용한 항공사진에서 다중클래스 차량 검출  와 를 이용한 고효율 전류 모드 급 전력증폭기 설계       기반 한국어 음성인식 모델 모델을 이용한 채팅 사용자 식별를 이용한 이미지 캡션 생성와 을 이용한 딥러닝 기반 특허 맵 모델를 활용한 주가 예측 모형 모델을 이용한 감정 분석와 을 이용한 딥러닝 기반 특허 맵 모델 기반 한국어 채팅체 문장 교정 모델용 주요 자재의 화재위험 대면적 에서 파워결합에 관한 실험적 연구 를 이용한 제작 및 특성에 관한 연구 최근 기술동향 연구개발 동향 와 을 활용한 문맥 인식 기반 인용 추천 모델 도입에 따른 해석 및 최적 모델링 구축이미지 기법을 이용한 실내 점군 프로젝션 시맨틱 분할 를 활용한 안전신문고 이미지 분류에 관한 연구 와 을 활용한 문맥 인식 기반 인용 추천 모델 기반의 동적 얼굴 표정 인식 시스템 를 위한 양방향 컨버터의 설계 기법 임피던스 불균형이 발전기 보호계전기에 미치는 영향 방법을 사용한 사고 탐지 와 을 이용한 모델의 디코더 속도 개선신약개발을 위한 기반의 딥러닝 모델  기반 한국어 음성인식변압기 의 역할  바이너리 코드를 이용한 기반 함수명 예측 여자시스템에 관한 연구  대한산업공학회 추계학술대회 과거 현재 그리고 미래반도체 변압기 소자 동향 과 의 직렬 아크 사고 측정 신호 비교 方形波 入力에 對한 의 應答特性에 關한 硏究 흡수식 히트펌프 보수와 운전 를 위한 구동용 인버터 트랜스포머의 설계와 응용경험 디자인의 관점에서 본 트랜스포머블 패션디자인의 발상글로컬문화콘텐츠의 원형 분석 트랜스포머를 중심으로 트랜스포머블 구조 시스템을 적용한 다목적 전시 공간 계획에 관한 연구 트랜스포머를 이용한 향상된 댓글 생성에 관한 연구유압 트랜스포머를 이용한 유압 실린더의 에너지 절감에 관한 연구비전 트랜스포머를 이용한 품질검사 관련 연구유압 트랜스포머를 이용한 유압 실린더의 에너지 절감에 관한 연구합성곱 신경망과 비전 트랜스포머를 활용한 포트홀과 맨홀 감지 성능 비교 해석을 위한 트랜스포머 권선 모델  전송 선로 트랜스포머를 이용한 고출력 고효율 광대역 전력 증폭기의 설계트랜스포머를 이용한 고전압 펄스 발생 장치의 설계와 측정평가에 관한 연구트랜스포머 기반 객체 검출트랜스포머 및 필터 사이즈를 줄일 수 있는 영전압 스위칭 레벨 컨버터압전 트랜스포머를 이용한 전력변환기 회로임피던스 트랜스포머에 의한 펄스 직류 전원 플라즈마의 전기 특성 변화 및 식각에 대한 영향 연구비전 트랜스포머를 이용한 휴대 수하물 보안검색 위험화물 검출 연구효율적인 트랜스포머를 이용한 팩트체크 자동화 모델 유압 트랜스포머를 이용한 에너지 절감형 유압시스템에 관한 기초연구효율적인 트랜스포머를 이용한 팩트체크 자동화 모델 유압 트랜스포머를 이용한 에너지 절감형 유압시스템에 관한 기초연구 트랜스포머의 커플링을 고려한 전력 분배기 설계현대패션에 나타난 트랜스포머블 디자인  트랜스포머를 이용한 고출력 조명용 정 전류 구동모듈 개발 프로그램을 활용한 트랜스포머블 웨딩드레스 디자인 개발 및 효율성 비교연구스몰웨딩용 웨딩드레스 디자인을 중심으로 형 밸런싱 트랜스포머를 적용한 초퍼 구동 시스템실리콘 에 적합한 면적 효율과 대칭성을 갖는 트랜스포머의 설계형 전류평형 트랜스포머를 이용한 고효율 구동시스템다중스케일 기반 비전 트랜스포머를 이용한 깊이 추정슬림형 의 백라이트 구동용 평판형 트랜스포머를 적용한 공진컨버터에 관한 연구다중램프 구동을 위한 집적화된 전류평형 트랜스포머 트랜스포머인덕터 설계용 도구의 현황 및 이용트랜스포머를 이용한 종단형 한국어영어 음성 번역트랜스포머를 이용한 다종 센서 기반 행동 인식트랜스포머를 이용한 밀러캐패시터 보상 밀리미터 대역 저 잡음 증폭기에 대한 연구트랜스포머를 이용한 초광대역 무선 신호 기반 사람의 자세 추정효율적인 트랜스포머에 기반한 설명 가능한 팩트체크 모델다중루프 트랜스포머를 활용한 전력증폭기 연구비전 트랜스포머를 이용한 색 항상성 기법고주파 트랜스포머의 권선배열에 기법 따른 손실해석사운드투벡터와 트랜스포머를 이용한 텍스트 정규화고주파용 평면 트랜스포머의 설계와 응용다공형 고주파 트랜스포머를 이용한 용 광대역 신호분배 분기기의 설계 제조기술 개발에 관한 연구 궤환회로 및 발룬 트랜스포머를 이용한 광대역 전력 전력증폭기 증폭기 설계역산란을 이용한 다단 임피던스 트랜스포머의 새로운 설계 방법 트랜스포머 최후의 기사 외북유럽 전통 니트 문양을 활용한 트랜스포머블 니트 디자인 연구코어없는 전자식 트랜스포머오토트랜스포머를 이용한 용 송신 누설 신호 제거기트랜스포머 자가 공진을 이용한 고전압 유전가열 연구멀티모달 패션 추천 대화 시스템을 위한 개선된 트랜스포머 모델경량화 기법을 적용한 트랜스포머 기반의 한국어 음성인식 연구투사적 그림검사 분야로의 트랜스포머 기반의 이미지 분류 모델 적용에 관한 연구 단어 인식기에 필요한 것은 트랜스포머넓은 입력 전압 범위에서 작은 트랜스포머 오프셋 전류를 가지는 비대칭 하프브리지 컨버터진단명 자동 레이블링을 위한 양방향 트랜스포머 사전학습 언어모델기반 최종진단명 분류 바나듐 레독스 흐름전지의 예측을 위한 트랜스포머 딥러닝 알고리즘에 대한 연구트랜스포머 기반 압타머단백질 상호작용 예측 분류 모델 설계트랜스포머 기반 다중 센서를 활용한 실차 소음 수준 예측 모델트랜스포머 기반 딥러닝 맵매칭 모델 개발트랜스포머 모델을 활용한 드노보 펩타이드 서열 분석트랜스포머 기반의 시계열 이상치 탐지 방법론트랜스포머 결합 밀리미터 웨이브 전력증폭기에 관한 연구트랜스포머 모델에 제로카피를 적용한 서빙 기법비전 트랜스포머 기반 연속 학습 트랜스포머 모델을 이용한 특허 질의응답 신경망 검색시스템프라다 트랜스포머 빠름과 느림의 대비가 전달하는 전율 트랜스포머 기반의 생성적 적대 신경망을 사용한 비정상 심장 박동 탐지 트랜스포머 프로젝트고주파 평면 트랜스포머 의 설계 트랜스포머 기반 하향 변환 믹서플라이백 다권선 트랜스포머 균등화 회로에서의 누설 인덕턴스 영향 보상  트랜스포머 최후의 기사 미이라 단어 손실함수를 추가한 트랜스포머 인코더디코더 기반의 제목 생성 모델과 를 이용한 트랜스포머 디코딩 속도 개선감성 사전을 활용한 트랜스포머 모델 기반의 감정분석단기 전력 수요예측을 위한 트랜스포머 모델 구조건축과 패션의 결합 프라다 트랜스포머 를 위한 적층형 압전트랜스포머의 설계 및 유한요소해석돌연변이 탐지를 위한 트랜스포머 모델과 모델의 성능비교 리더에서의 오토트랜스포머를 이용한 송신 누설 신호 제거기어플리케이션 호출 속도 향상을 위한 트랜스포머 모델 기반 안드로이드 비디오 ...

# %% [markdown]
# ### 품사 태깅 : 명사 추출

# %%
nlp = Okt()
message_N = nlp.nouns(all_str)
message_N   #출력하여 내용 확인
# Out:
# ['의',
#  '관',
#  '무인',
#  '감시',
#  '심층',
#  '학습',
#  '방법',
#  '사용',
#  '층',
#  '수평',
#  '시계열',
#  '데이터',
#  '분석',
#  '내부',
#  '발생',
#  '신호',
#  '패턴',
#  '분석',
#  '위',
#  '적용',
#  '결과',
#  '비교',
#  '내부',
#  '발생',
#  '신호',
#  '패턴',
#  '분석',
#  '위',
#  '적용',
#  '결과',
#  '비교',
#  '출력',
#  '단',
#  '로',
#  '통합',
#  '설계',
#  '효율',
#  '용',
#  '전원',
#  '시스템',
#  '기반',
#  '번역',
#  '문',
#  '사후',
#  '교정',
#  '원시',
#  '문과',
#  '기계번역',
#  '문',
#  '간',
#  '효과',
#  '관계',
#  '모델링',
#  '통한',
#  '기반',
#  '번역',
#  '문',
#  '자동',
#  '사후',
#  '교정',
#  '를',
#  '응용',
#  '전류',
#  '구동',
#  '관',
#  '연구',
#  '를',
#  '의',
#  '회로',
#  '를',
#  '이용',
#  '고온',
#  '초전도',
#  '케이블',
#  '층',
#  '전류',
#  '등분배',
#  '방안',
#  '활용',
#  '전이',
#  '학습',
#  '효과',
#  '검증',
#  '연구',
#  '법률',
#  '상담',
#  '데이터',
#  '분류',
#  '문제',
#  '적용',
#  '를',
#  '이용',
#  '고온',
#  '초전도',
#  '케이블',
#  '층',
#  '전류',
#  '등분배',
#  '방안',
#  '를',
#  '이용',
#  '계통',
#  '혼잡',
#  '처리',
#  '방안',
#  '의',
#  '동작',
#  '해석',
#  '용',
#  '개발',
#  '의',
#  '노이즈',
#  '성능',
#  '분석',
#  '용',
#  '개발',
#  '사례',
#  '다중',
#  '인코더',
#  '기반',
#  '번역',
#  '문',
#  '자동',
#  '사후',
#  '교정',
#  '모델',
#  '디코더',
#  '구조',
#  '연구',
#  '를',
#  '위',
#  '방향',
#  '컨버터',
#  '최적',
#  '설계',
#  '의',
#  '전철',
#  '용',
#  '주파',
#  '대전',
#  '비정질',
#  '개발',
#  '내부',
#  '발생',
#  '신호',
#  '패턴',
#  '분석',
#  '위',
#  '적용',
#  '결과',
#  '비교',
#  '의',
#  '다중',
#  '권선',
#  '전류',
#  '불균형',
#  '현상',
#  '분석',
#  '출력',
#  '를',
#  '계통',
#  '혼잡',
#  '처리',
#  '위',
#  '의',
#  '최적',
#  '위치',
#  '선정',
#  '권선구',
#  '해석',
#  '여자',
#  '전압',
#  '파형',
#  '의',
#  '특성',
#  '초',
#  '고압',
#  '의',
#  '장기',
#  '과전압',
#  '시험',
#  '관',
#  '연구',
#  '광원',
#  '광',
#  '의',
#  '출력',
#  '특성',
#  '연구',
#  '측정',
#  '기술',
#  '연구',
#  '출력',
#  '단',
#  '로',
#  '통합',
#  '설계',
#  '효율',
#  '용',
#  '시스템',
#  '딥',
#  '러닝',
#  '이용',
#  '지수',
#  '변동성',
#  '추정',
#  '위',
#  '기반',
#  '자세',
#  '추정',
#  '기법',
#  '네트워크',
#  '이용',
#  '음성',
#  '신호',
#  '변환',
#  '기반',
#  '번역',
#  '문',
#  '사후',
#  '교정',
#  '위협',
#  '탐지',
#  '및',
#  '교통량',
#  '예측',
#  '위',
#  '장기',
#  '시계열',
#  '데이터',
#  '모델',
#  '성능',
#  '비교',
#  '를',
#  '이용',
#  '항공사진',
#  '다중',
#  '클래스',
#  '차량',
#  '검',
#  '를',
#  '이용',
#  '효율',
#  '전류',
#  '모드',
#  '급',
#  '전력',
#  '증폭기',
#  '설계',
#  '기반',
#  '한국어',
#  '음성인식',
#  '모델',
#  '모델',
#  '이용',
#  '채팅',
#  '사용자',
#  '식별',
#  '를',
#  '이용',
#  '이미지',
#  '캡션',
#  '생',
#  '이용',
#  '딥',
#  '러닝',
#  '기반',
#  '특허',
#  '맵',
#  '모델',
#  '를',
#  '활용',
#  '주가',
#  '예측',
#  '모형',
#  '모델',
#  '이용',
#  '감정',
#  '분석',
#  '이용',
#  '딥',
#  '러닝',
#  '기반',
#  '특허',
#  '맵',
#  '모델',
#  '기반',
#  '한국어',
#  '채팅',
#  '체',
#  '문장',
#  '교정',
#  '모델',
#  '용',
#  '주요',
#  '자재',
#  '화재',
#  '위험',
#  '대면',
#  '파워',
#  '결합',
#  '관',
#  '실험',
#  '연구',
#  '를',
#  '이용',
#  '제작',
#  '및',
#  '특성',
#  '관',
#  '연구',
#  '최근',
#  '기술',
#  '동향',
#  '연구개발',
#  '동향',
#  '활용',
#  '문맥',
#  '인식',
#  '기반',
#  '인용',
#  '추천',
#  '모델',
#  '도입',
#  '해석',
#  '및',
#  '최적',
#  '모델링',
#  '구축',
#  '이미지',
#  '기법',
#  '이용',
#  '실내',
#  '점군',
#  '프로',
#  '젝션',
#  '맨',
#  '분할',
#  '를',
#  '활용',
#  '안전',
#  '신문고',
#  '이미지',
#  '분류',
#  '관',
#  '연구',
#  '활용',
#  '문맥',
#  '인식',
#  '기반',
#  '인용',
#  '추천',
#  '모델',
#  '기반',
#  '적',
#  '얼굴',
#  '표정',
#  '인식',
#  '시스템',
#  '를',
#  '위',
#  '방향',
#  '컨버터',
#  '설계',
#  '기법',
#  '임피던스',
#  '불균형',
#  '발전기',
#  '보호',
#  '계전기',
#  '영향',
#  '방법',
#  '사용',
#  '사고',
#  '탐지',
#  '이용',
#  '모델',
#  '디코더',
#  '속도',
#  '개선',
#  '개발',
#  '위',
#  '기반',
#  '딥',
#  '러닝',
#  '모델',
#  '기반',
#  '한국어',
#  '음성인식',
#  '변압기',
#  '의',
#  '역할',
#  '바이너리',
#  '코드',
#  '이용',
#  '기반',
#  '함수',
#  '예측',
#  '여자',
#  '시스템',
#  '관',
#  '연구',
#  '산업',
#  '학회',
#  '추계',
#  '학술',
#  '대회',
#  '과거',
#  '현재',
#  '미래',
#  '반도체',
#  '변압기',
#  '소자',
#  '동향',
#  '과',
#  '의',
#  '직렬',
#  '아크',
#  '사고',
#  '측정',
#  '신호',
#  '비교',
#  '의',
#  '흡수',
#  '히트',
#  '펌프',
#  '보수',
#  '운전',
#  '를',
#  '위',
#  '용',
#  '인버터',
#  '트랜스포머',
#  '설계',
#  '응용',
#  '경험',
#  '디자인',
#  '관점',
#  '트랜스포머',
#  '블',
#  '패션',
#  '디자인',
#  '발상',
#  '글',
#  '컬',
#  '문화',
#  '콘텐츠',
#  '원형',
#  '분석',
#  '트랜스포머',
#  '중심',
#  '트랜스포머',
#  '블',
#  '구조',
#  '시스템',
#  '적용',
#  '목적',
#  '전시',
#  '공간',
#  '계획',
#  '관',
#  '연구',
#  '트랜스포머',
#  '이용',
#  '향상',
#  '댓글',
#  '생',
#  '관',
#  '구유',
#  '압',
#  '트랜스포머',
#  '이용',
#  '유압',
#  '실린더',
#  '에너지',
#  '절감',
#  '관',
#  '연구',
#  '트랜스포머',
#  '이용',
#  '품질',
#  '검사',
#  '관련',
#  '구유',
#  '압',
#  '트랜스포머',
#  '이용',
#  '유압',
#  '실린더',
#  '에너지',
#  '절감',
#  '관',
#  '연구',
#  '합성곱',
#  '신경망',
#  '트랜스포머',
#  '활용',
#  '포트홀',
#  '맨홀',
#  '감지',
#  '성능',
#  '비교',
#  '해석',
#  '위',
#  '트랜스포머',
#  '권선',
#  '모델',
#  '전송',
#  '선로',
#  '트랜스포머',
#  '이용',
#  '출력',
#  '효율',
#  '광대역',
#  '전력',
#  '증폭기',
#  '설계',
#  '트랜스포머',
#  '이용',
#  '전압',
#  '펄스',
#  '발생',
#  '장치',
#  '설계',
#  '측정',
#  '평가',
#  '관',
#  '연구',
#  '트랜스포머',
#  '기반',
#  '객체',
#  '검',
#  '트랜스포머',
#  '및',
#  '필터',
#  '사이즈',
#  '수',
#  '전압',
#  '스위칭',
#  '레벨',
#  '컨버터',
#  '압전',
#  '트랜스포머',
#  '이용',
#  '전력',
#  '변환기',
#  '회로',
#  '임피던스',
#  '트랜스포머',
#  '펄스',
#  '직류',
#  '전원',
#  '플라즈마',
#  '전기',
#  '특성',
#  '변화',
#  '및',
#  '식각',
#  '대한',
#  '영향',
#  '연구',
#  '트랜스포머',
#  '이용',
#  '휴대',
#  '수하물',
#  '보안',
#  '검색',
#  '위험',
#  '화물',
#  '검',
#  '효율',
#  '트랜스포머',
#  '이용',
#  '팩트',
#  '체크',
#  '자동화',
#  '모델',
#  '유압',
#  '트랜스포머',
#  '이용',
#  '에너지',
#  '절감',
#  '유압',
#  '시스템',
#  '관',
#  '기초',
#  '효율',
#  '트랜스포머',
#  '이용',
#  '팩트',
#  '체크',
#  '자동화',
#  '모델',
#  '유압',
#  '트랜스포머',
#  '이용',
#  '에너지',
#  '절감',
#  '유압',
#  '시스템',
#  '관',
#  '기초',
#  '연구',
#  '트랜스포머',
#  '커플링',
#  '고려',
#  '전력',
#  '분배',
#  '기',
#  '설계',
#  '현대',
#  '패션',
#  '트랜스포머',
#  '블',
#  '디자인',
#  '트랜스포머',
#  '이용',
#  '출력',
#  '조명',
#  '용',
#  '정',
#  '전류',
#  '모듈',
#  '개발',
#  '프로그램',
#  '활용',
#  '트랜스포머',
#  '블',
#  '웨딩드레스',
#  '디자인',
#  '개발',
#  '및',
#  '효율',
#  '비교',
#  '연구',
#  '스몰',
#  '웨딩',
#  '용',
#  '웨딩드레스',
#  '디자인',
#  '중심',
#  '형',
#  '밸런싱',
#  '트랜스포머',
#  '적용',
#  '초퍼',
#  '구동',
#  '시스템',
#  '실리콘',
#  '면적',
#  '효율',
#  '대칭성',
#  '트랜스포머',
#  '설계',
#  '전류',
#  '평형',
#  '트랜스포머',
#  '이용',
#  '효율',
#  '시스템',
#  '다중',
#  '스케일',
#  '기반',
#  '트랜스포머',
#  '이용',
#  '깊이',
#  '추정',
#  '슬림',
#  '의',
#  '백라이트',
#  '용',
#  '평판',
#  '트랜스포머',
#  '적용',
#  '공진',
#  '컨버터',
#  '관',
#  '연구',
#  '다중',
#  '램프',
#  '구동',
#  '위',
#  '집',
#  '화',
#  '전류',
#  '평형',
#  '트랜스포머',
#  '트랜스포머',
#  '인덕터',
#  '도구',
#  '현황',
#  '및',
#  '이용',
#  '트랜스포머',
#  '이용',
#  '종단',
#  '한국어',
#  '영어',
#  '음성',
#  '번역',
#  '트랜스포머',
#  '이용',
#  '종',
#  '센서',
#  '기반',
#  '행동',
#  '인식',
#  '트랜스포머',
#  '이용',
#  '밀러',
#  '캐패시터',
#  '보상',
#  '밀리미터',
#  '대역',
#  '저',
#  '잡음',
#  '증폭기',
#  '대한',
#  '트랜스포머',
#  '이용',
#  '초광대역',
#  '무선',
#  '신호',
#  '기반',
#  '사람',
#  '자세',
#  '추정',
#  '효율',
#  '트랜스포머',
#  '기반',
#  '설명',
#  '팩트',
#  '체크',
#  '모델',
#  '다중',
#  '루프',
#  '트랜스포머',
#  '활용',
#  '전력',
#  '증폭기',
#  '연구',
#  '트랜스포머',
#  '이용',
#  '색',
#  '항상성',
#  '기법',
#  '주파',
#  '트랜스포머',
#  '권선',
#  '배열',
#  '기법',
#  '손실',
#  '사운드',
#  '투',
#  '벡터',
#  '트랜스포머',
#  '이용',
#  '텍스트',
#  '정규화',
#  '주파',
#  '용',
#  '평면',
#  '트랜스포머',
#  '설계',
#  '응용',
#  '다공',
#  '주파',
#  '트랜스포머',
#  '이용',
#  '용',
#  '광대역',
#  '신호',
#  '분배',
#  '분기기',
#  '설계',
#  '제조',
#  '기술',
#  '개발',
#  '관',
#  '연구',
#  '궤환',
#  '회로',
#  '및',
#  '발룬',
#  '트랜스포머',
#  '이용',
#  '광대역',
#  '전력',
#  '전력',
#  '증폭기',
#  '증폭기',
#  '설계',
#  '역',
#  '산란',
#  '이용',
#  '다단',
#  '임피던스',
#  '트랜스포머',
#  '설계',
#  '방법',
#  '트랜스포머',
#  '최후',
#  '기사',
#  '외',
#  '북유럽',
#  '전통',
#  '니트',
#  '양',
#  '활용',
#  '트랜스포머',
#  '블',
#  '니트',
#  '디자인',
#  '코어',
#  '자식',
#  '트랜스포머',
#  '오토',
#  '트랜스포머',
#  '이용',
#  '용',
#  '송신',
#  '누설',
#  '신호',
#  '제거',
#  '트랜스포머',
#  '자가',
#  '공진',
#  '이용',
#  '전압',
#  '유전',
#  '가열',
#  '멀티',
#  '달',
#  '패션',
#  '추천',
#  '대화',
#  '시스템',
#  '위',
#  '개선',
#  '트랜스포머',
#  '모델',
#  '경량',
#  '기법',
#  '적용',
#  '트랜스포머',
#  '기반',
#  '한국어',
#  '음성인식',
#  '투사',
#  '그림',
#  '검사',
#  '분야',
#  '의',
#  '트랜스포머',
#  '기반',
#  '이미지',
#  '분류',
#  '모델',
#  '적용',
#  '관',
#  '연구',
#  '단어',
#  '인식',
#  '기',
#  '것',
#  '트랜스포머',
#  '입력',
#  '전압',
#  '범위',
#  '트랜스포머',
#  '오프셋',
#  '전류',
#  '비',
#  '대칭',
#  '하프',
#  '브리지',
#  '컨버터',
#  '진단',
#  '자동',
#  '레이블',
#  '링',
#  '위',
#  '방향',
#  '트랜스포머',
#  '사전',
#  '학습',
#  '언어',
#  '모델',
#  '기반',
#  '최종진',
#  '단명',
#  '분류',
#  '바나듐',
#  '레독스',
#  '예측',
#  '위',
#  '트랜스포머',
#  '딥',
#  '러닝',
#  '알고리즘',
#  '대한',
#  '연구',
#  '트랜스포머',
#  '기반',
#  '압',
#  '머',
#  '단백질',
#  '상호작용',
#  '예측',
#  '분류',
#  '모델',
#  '설계',
#  '트랜스포머',
#  '기반',
#  '다중',
#  '센서',
#  '활용',
#  '실차',
#  '소음',
#  '수준',
#  '예측',
#  '모델',
#  '트랜스포머',
#  '기반',
#  '딥',
#  '러닝',
#  '맵',
#  '매칭',
#  '모델',
#  '개발',
#  '트랜스포머',
#  '모델',
#  '활용',
#  '드노',
#  '보',
#  '펩타이드',
#  '서열',
#  '분석',
#  '트랜스포머',
#  '기반',
#  '시계열',
#  '상치',
#  '탐지',
#  '방법론',
#  '트랜스포머',
#  '결합',
#  '밀리미터',
#  '웨이브',
#  '전력',
#  '증폭기',
#  '관',
#  '연구',
#  '트랜스포머',
#  '모델',
#  '제로',
#  '카피',
#  '적용',
#  '서빙',
#  '기법',
#  '트랜스포머',
#  '기반',
#  '연속',
#  '학습',
#  '트랜스포머',
#  '모델',
#  '이용',
#  '특허',
#  '질의',
#  '응답',
#  '신경망',
#  '검색',
#  '시스템',
#  '프라다',
#  '트랜스포머',
#  '대비',
#  '전달',
#  '전율',
#  '트랜스포머',
#  '기반',
#  '생',
#  '성적',
#  '적대',
#  '신경망',
#  '사용',
#  '비정상',
#  '심장',
#  '박동',
#  '탐지',
#  '트랜스포머',
#  '프로젝트',
#  '주파',
#  '평면',
#  '트랜스포머',
#  '의',
#  '설계',
#  '트랜스포머',
#  '기반',
#  '하향',
#  '변환',
#  '믹서',
#  ...]

# %% [markdown]
# ### 단어 빈도 탐색

# %%
count = Counter(message_N)

count   #출력하여 내용 확인
# Out:
# Counter({'의': 25,
#          '관': 69,
#          '무인': 1,
#          '감시': 2,
#          '심층': 1,
#          '학습': 14,
#          '방법': 18,
#          '사용': 12,
#          '층': 5,
#          '수평': 1,
#          '시계열': 3,
#          '데이터': 6,
#          '분석': 44,
#          '내부': 4,
#          '발생': 8,
#          '신호': 16,
#          '패턴': 4,
#          '위': 58,
#          '적용': 24,
#          '결과': 4,
#          '비교': 14,
#          '출력': 9,
#          '단': 2,
#          '로': 3,
#          '통합': 2,
#          '설계': 50,
#          '효율': 25,
#          '용': 57,
#          '전원': 9,
#          '시스템': 27,
#          '기반': 64,
#          '번역': 6,
#          '문': 6,
#          '사후': 5,
#          '교정': 7,
#          '원시': 1,
#          '문과': 1,
#          '기계번역': 1,
#          '간': 1,
#          '효과': 6,
#          '관계': 2,
#          '모델링': 8,
#          '통한': 5,
#          '자동': 7,
#          '를': 31,
#          '응용': 7,
#          '전류': 33,
#          '구동': 12,
#          '연구': 91,
#          '회로': 18,
#          '이용': 116,
#          '고온': 6,
#          '초전도': 9,
#          '케이블': 2,
#          '등분배': 2,
#          '방안': 8,
#          '활용': 19,
#          '전이': 2,
#          '검증': 1,
#          '법률': 1,
#          '상담': 1,
#          '분류': 8,
#          '문제': 1,
#          '계통': 11,
#          '혼잡': 2,
#          '처리': 5,
#          '동작': 11,
#          '해석': 19,
#          '개발': 20,
#          '노이즈': 2,
#          '성능': 14,
#          '사례': 2,
#          '다중': 10,
#          '인코더': 4,
#          '모델': 48,
#          '디코더': 5,
#          '구조': 10,
#          '방향': 7,
#          '컨버터': 24,
#          '최적': 8,
#          '전철': 4,
#          '주파': 8,
#          '대전': 2,
#          '비정질': 1,
#          '권선': 16,
#          '불균형': 2,
#          '현상': 3,
#          '위치': 1,
#          '선정': 1,
#          '권선구': 1,
#          '여자': 4,
#          '전압': 18,
#          '파형': 1,
#          '특성': 79,
#          '초': 3,
#          '고압': 2,
#          '장기': 2,
#          '과전압': 1,
#          '시험': 6,
#          '광원': 2,
#          '광': 1,
#          '측정': 10,
#          '기술': 7,
#          '딥': 6,
#          '러닝': 6,
#          '지수': 1,
#          '변동성': 1,
#          '추정': 5,
#          '자세': 3,
#          '기법': 18,
#          '네트워크': 1,
#          '음성': 5,
#          '변환': 7,
#          '위협': 1,
#          '탐지': 6,
#          '및': 51,
#          '교통량': 1,
#          '예측': 12,
#          '항공사진': 1,
#          '클래스': 1,
#          '차량': 1,
#          '검': 5,
#          '모드': 7,
#          '급': 7,
#          '전력': 24,
#          '증폭기': 7,
#          '한국어': 10,
#          '음성인식': 3,
#          '채팅': 2,
#          '사용자': 1,
#          '식별': 1,
#          '이미지': 7,
#          '캡션': 2,
#          '생': 9,
#          '특허': 3,
#          '맵': 4,
#          '주가': 1,
#          '모형': 1,
#          '감정': 2,
#          '체': 1,
#          '문장': 2,
#          '주요': 1,
#          '자재': 1,
#          '화재': 3,
#          '위험': 2,
#          '대면': 1,
#          '파워': 1,
#          '결합': 6,
#          '실험': 2,
#          '제작': 7,
#          '최근': 1,
#          '동향': 4,
#          '연구개발': 1,
#          '문맥': 4,
#          '인식': 8,
#          '인용': 2,
#          '추천': 3,
#          '도입': 2,
#          '구축': 2,
#          '실내': 1,
#          '점군': 1,
#          '프로': 1,
#          '젝션': 1,
#          '맨': 2,
#          '분할': 2,
#          '안전': 1,
#          '신문고': 1,
#          '적': 2,
#          '얼굴': 1,
#          '표정': 1,
#          '임피던스': 12,
#          '발전기': 1,
#          '보호': 6,
#          '계전기': 2,
#          '영향': 13,
#          '사고': 2,
#          '속도': 6,
#          '개선': 6,
#          '변압기': 144,
#          '역할': 1,
#          '바이너리': 1,
#          '코드': 2,
#          '함수': 1,
#          '산업': 2,
#          '학회': 1,
#          '추계': 1,
#          '학술': 1,
#          '대회': 1,
#          '과거': 1,
#          '현재': 1,
#          '미래': 1,
#          '반도체': 1,
#          '소자': 2,
#          '과': 1,
#          '직렬': 6,
#          '아크': 1,
#          '흡수': 2,
#          '히트': 2,
#          '펌프': 1,
#          '보수': 1,
#          '운전': 3,
#          '인버터': 9,
#          '트랜스포머': 192,
#          '경험': 1,
#          '디자인': 13,
#          '관점': 2,
#          '블': 6,
#          '패션': 5,
#          '발상': 1,
#          '글': 1,
#          '컬': 1,
#          '문화': 1,
#          '콘텐츠': 1,
#          '원형': 2,
#          '중심': 8,
#          '목적': 1,
#          '전시': 1,
#          '공간': 1,
#          '계획': 1,
#          '향상': 11,
#          '댓글': 2,
#          '구유': 2,
#          '압': 23,
#          '유압': 6,
#          '실린더': 2,
#          '에너지': 7,
#          '절감': 5,
#          '품질': 2,
#          '검사': 3,
#          '관련': 2,
#          '합성곱': 1,
#          '신경망': 6,
#          '포트홀': 1,
#          '맨홀': 1,
#          '감지': 2,
#          '전송': 5,
#          '선로': 3,
#          '광대역': 7,
#          '펄스': 9,
#          '장치': 12,
#          '평가': 9,
#          '객체': 3,
#          '필터': 4,
#          '사이즈': 1,
#          '수': 2,
#          '스위칭': 4,
#          '레벨': 1,
#          '압전': 9,
#          '변환기': 11,
#          '직류': 3,
#          '플라즈마': 1,
#          '전기': 2,
#          '변화': 6,
#          '식각': 1,
#          '대한': 11,
#          '휴대': 1,
#          '수하물': 2,
#          '보안': 3,
#          '검색': 4,
#          '화물': 1,
#          '팩트': 3,
#          '체크': 3,
#          '자동화': 3,
#          '기초': 2,
#          '커플링': 1,
#          '고려': 8,
#          '분배': 3,
#          '기': 6,
#          '현대': 1,
#          '조명': 4,
#          '정': 1,
#          '모듈': 6,
#          '프로그램': 2,
#          '웨딩드레스': 2,
#          '스몰': 1,
#          '웨딩': 1,
#          '형': 5,
#          '밸런싱': 3,
#          '초퍼': 1,
#          '실리콘': 1,
#          '면적': 1,
#          '대칭성': 1,
#          '평형': 7,
#          '스케일': 1,
#          '깊이': 1,
#          '슬림': 1,
#          '백라이트': 2,
#          '평판': 2,
#          '공진': 12,
#          '램프': 5,
#          '집': 4,
#          '화': 9,
#          '인덕터': 2,
#          '도구': 1,
#          '현황': 1,
#          '종단': 1,
#          '영어': 1,
#          '종': 1,
#          '센서': 6,
#          '행동': 1,
#          '밀러': 1,
#          '캐패시터': 1,
#          '보상': 4,
#          '밀리미터': 2,
#          '대역': 1,
#          '저': 1,
#          '잡음': 1,
#          '초광대역': 2,
#          '무선': 4,
#          '사람': 2,
#          '설명': 1,
#          '루프': 1,
#          '색': 1,
#          '항상성': 1,
#          '배열': 1,
#          '손실': 7,
#          '사운드': 1,
#          '투': 1,
#          '벡터': 3,
#          '텍스트': 5,
#          '정규화': 2,
#          '평면': 4,
#          '다공': 1,
#          '분기기': 1,
#          '제조': 2,
#          '궤환': 1,
#          '발룬': 2,
#          '역': 1,
#          '산란': 1,
#          '다단': 1,
#          '최후': 2,
#          '기사': 2,
#          '외': 1,
#          '북유럽': 1,
#          '전통': 1,
#          '니트': 2,
#          '양': 1,
#          '코어': 5,
#          '자식': 3,
#          '오토': 2,
#          '송신': 2,
#          '누설': 3,
#          '제거': 3,
#          '자가': 8,
#          '유전': 2,
#          '가열': 1,
#          '멀티': 5,
#          '달': 4,
#          '대화': 1,
#          '경량': 1,
#          '투사': 1,
#          '그림': 1,
#          '분야': 1,
#          '단어': 3,
#          '것': 1,
#          '입력': 4,
#          '범위': 2,
#          '오프셋': 2,
#          '비': 7,
#          '대칭': 3,
#          '하프': 2,
#          '브리지': 4,
#          '진단': 10,
#          '레이블': 2,
#          '링': 3,
#          '사전': 5,
#          '언어': 4,
#          '최종진': 2,
#          '단명': 2,
#          '바나듐': 1,
#          '레독스': 1,
#          '알고리즘': 9,
#          '머': 1,
#          '단백질': 1,
#          '상호작용': 1,
#          '실차': 1,
#          '소음': 5,
#          '수준': 1,
#          '매칭': 2,
#          '드노': 1,
#          '보': 1,
#          '펩타이드': 1,
#          '서열': 1,
#          '상치': 1,
#          '방법론': 1,
#          '웨이브': 1,
#          '제로': 1,
#          '카피': 1,
#          '서빙': 1,
#          '연속': 1,
#          '질의': 4,
#          '응답': 4,
#          '프라다': 2,
#          '대비': 1,
#          '전달': 3,
#          '전율': 1,
#          '성적': 1,
#          '적대': 2,
#          '비정상': 1,
#          '심장': 1,
#          '박동': 1,
#          '프로젝트': 1,
#          '하향': 1,
#          '믹서': 1,
#          '플라이': 5,
#          '균등': 1,
#          '인덕턴스': 1,
#          '미이라': 1,
#          '손실함수': 3,
#          '추가': 2,
#          '제목': 2,
#          '디코딩': 1,
#          '감성': 1,
#          '단기': 1,
#          '건축': 1,
#          '적층': 4,
#          '유한': 1,
#          '요소': 1,
#          '돌연변이': 1,
#          '리더': 1,
#          '어플리케이션': 1,
#          '호출': 1,
#          '안드로이드': 1,
#          '비디오': 2,
#          '환경': 1,
#          '상향': 1,
#          '링크': 1,
#          '자원': 1,
#          '웨어': 1,
#          '러블': 1,
#          '디바이스': 1,
#          '교호': 1,
#          '작용': 1,
#          '파악': 2,
#          '지도': 2,
#          '여객': 1,
#          '악성코드': 1,
#          '제어': 6,
#          '흐름': 1,
#          '트리플': 1,
#          '렛': 1,
#          '그래프': 1,
#          '외부': 1,
#          '자극': 1,
#          '감응': 1,
#          '지능': 3,
#          '자기': 4,
#          '조립': 1,
#          '나노': 2,
#          '밀도': 2,
#          '융합': 5,
#          '소통': 1,
#          '주의': 1,
#          '컨테이너': 2,
#          '변형': 2,
#          '윤리': 1,
#          '차': 9,
#          '과도': 2,
#          '영상': 2,
#          '억제': 2,
#          '형태소': 2,
#          '캐릭터': 2,
#          '고찰': 5,
#          '아동': 1,
#          '완구': 1,
#          '제품': 1,
#          '축선': 1,
#          '메타포': 1,
#          '시각디자인': 1,
#          '가치': 2,
#          '실용': 2,
#          '경제': 1,
#          '딩': 1,
#          '와이어': 3,
#          '수직': 1,
#          '지속가능성': 1,
#          '모티브': 1,
#          '지속': 1,
#          '변신': 3,
#          '주제': 1,
#          '본드': 2,
#          '요약': 3,
#          '순차': 1,
#          '구현': 4,
#          '플래쉬': 1,
#          '방전': 7,
#          '이론': 1,
#          '정보보안': 1,
#          '에코디자인': 1,
#          '개념': 3,
#          '에코': 1,
#          '수용': 1,
#          '종류': 1,
#          '두': 2,
#          '개': 4,
#          '연결': 2,
#          '위상': 5,
#          '천이': 1,
#          '풀': 5,
#          '브릿지': 3,
#          '가형': 1,
#          '자막': 1,
#          '회전': 2,
#          '교열': 1,
#          '관용': 3,
#          '냉각': 11,
#          '의미': 2,
#          '유사': 1,
#          '자연어이해': 1,
#          '의도': 1,
#          '클라이스트론': 3,
#          '부하': 11,
#          '대출': 1,
#          '계': 4,
#          '세라믹스': 8,
#          '기적': 15,
#          '발진': 2,
#          '플래시': 2,
#          '그': 4,
#          '리플': 1,
#          '정전': 1,
#          '류': 1,
#          '태그': 1,
#          '라벨': 1,
#          '선형': 2,
#          '속기': 1,
#          '고': 1,
#          '평균': 1,
#          '수중': 1,
#          '음향': 1,
#          '트랜스': 2,
#          '듀': 1,
#          '송수': 1,
#          '신': 1,
#          '공유': 1,
#          '너': 1,
#          '토로': 1,
#          '정류': 3,
#          '커패시터': 1,
#          '축': 2,
#          '셀': 1,
#          '배터리': 1,
#          '팩': 1,
#          '중대': 1,
#          '용량': 5,
#          '권': 1,
#          '선법': 1,
#          '소형': 7,
#          '자계': 2,
#          '분포': 3,
#          '중': 3,
#          '강하': 2,
#          '반복': 1,
#          '페널티': 1,
#          '어': 1,
#          '텐션': 1,
#          '경사': 1,
#          '화이트': 1,
#          '박스': 1,
#          '예제': 1,
#          '에어': 1,
#          '수기': 1,
#          '열전달': 2,
#          '스페이스': 1,
#          '유동': 2,
#          '경계': 1,
#          '숫자': 1,
#          '냉음극관': 1,
#          '감정인': 1,
#          '다중작업': 1,
#          '형광등': 1,
#          '안정': 1,
#          '투자율': 1,
#          '마이크로': 3,
#          '조성': 1,
#          '강압': 2,
#          '정류기': 1,
#          '첨가': 2,
#          '미세': 1,
#          '스위치': 4,
#          '라인': 4,
#          '로컬': 1,
#          '프레임': 1,
#          '변경': 2,
#          '증강': 1,
#          '박막': 2,
#          '스트립': 1,
#          '인의': 1,
#          '두께': 1,
#          '윤곽': 1,
#          '진동': 5,
#          '오일': 4,
#          '내': 2,
#          '광섬유': 1,
#          '음압': 1,
#          '승압형': 1,
#          '듀얼': 2,
#          '구성': 3,
#          '절연': 13,
#          '게이트': 2,
#          '임': 2,
#          '정보': 2,
#          '추출': 1,
#          '상병': 1,
#          '리': 1,
#          '후': 1,
#          '유형': 1,
#          '분류기': 1,
#          '접촉': 1,
#          '감': 4,
#          '시뮬레이션': 2,
#          '원거리': 1,
#          '통신': 1,
#          '소재': 1,
#          '미적': 1,
#          '인자': 1,
#          '도출': 2,
#          '미세먼지': 1,
#          '시공간': 1,
#          '영화': 2,
#          '엘리시움': 1,
#          '티브': 1,
#          '트랜스휴머니즘': 1,
#          '캡셔닝': 1,
#          '인코딩': 1,
#          '가스': 4,
#          '온라인': 3,
#          '부분': 6,
#          '포화': 2,
#          '상태': 1,
#          '코': 1,
#          '형상': 1,
#          '주상': 5,
#          '고장': 6,
#          '경관': 1,
#          '초음파': 3,
#          '상시': 2,
#          '온도': 8,
#          '재': 1,
#          '설정': 2,
#          '몰드': 11,
#          '검출기': 1,
#          '술': 1,
#          '망': 2,
#          '상': 4,
#          '시간': 1,
#          '영역': 2,
#          '부의': 1,
#          '장검': 1,
#          '유': 3,
#          '코로나': 2,
#          '전문가': 1,
#          '유입': 8,
#          '결함': 1,
#          '로직': 2,
#          '롤': 1,
#          '돌입': 2,
#          '도제': 1,
#          '최대': 1,
#          '덕트': 2,
#          '자연': 1,
#          '대류': 1,
#          '변압': 3,
#          '기용': 7,
#          '방열기': 1,
#          '채널': 3,
#          '방열': 1,
#          '이하': 1,
#          '변성기': 8,
#          '치': 1,
#          '뉴': 1,
#          '동력': 1,
#          '분산': 1,
#          '고속': 3,
#          '철': 2,
#          '도용': 2,
#          '자성재료': 1,
#          '형태': 1,
#          '함유': 1,
#          '유의': 4,
#          '화학': 1,
#          '복합': 1,
#          '철심': 1,
#          '액체질소': 1,
#          '파괴': 1,
#          '현장': 2,
#          '초소': 1,
#          '저항': 4,
#          '한기': 4,
#          '히스테리시스': 2,
#          '보호방식': 1,
#          '동일': 1,
#          '분극': 1,
#          '디스크': 2,
#          '승': 1,
#          '치밀': 1,
#          '기전력': 1,
#          '소결': 1,
#          '수명': 2,
#          '가속': 1,
#          '물의': 1,
#          '열': 2,
#          '상관': 1,
#          '계수': 1,
#          '배전': 4,
#          '관리': 3,
#          '광범위': 1,
#          '오차': 2,
#          '표준': 1,
#          '육각형': 1,
#          '표면': 1,
#          '금속': 2,
#          '물질': 2,
#          '극초단파': 1,
#          '판': 1,
#          '상용': 2,
#          '초전도체': 1,
#          '상전': 1,
#          '도체': 1,
#          '한류': 1,
#          '기기': 1,
#          '세라믹': 3,
#          '감압': 2,
#          '변전소': 2,
#          '조건': 2,
#          '팬': 1,
#          '변류기': 1,
#          '개방': 1,
#          '난': 2,
#          '연성': 2,
#          '방지': 2,
#          '신경': 1,
#          '조물': 1,
#          '외함': 1,
#          '재질': 1,
#          '배': 2,
#          '전용': 2,
#          '표류': 1,
#          '손': 3,
#          '필름': 1,
#          '자산': 1,
#          '투자': 1,
#          '최적화': 1,
#          '기지': 1,
#          '유체': 1,
#          '증량제': 1,
#          '혼합': 2,
#          '비율': 1,
#          '기와': 1,
#          '정밀': 1,
#          '션트': 1,
#          '변성': 1,
#          '부담': 1,
#          '정합': 2,
#          '자속': 2,
#          '계전': 1,
#          '점': 1,
#          '용접': 1,
#          '랜덤': 1,
#          '철도차량': 2,
#          '주': 1,
#          '과부': 1,
#          '절': 3,
#          '연유': 3,
#          '화검': 1,
#          '단상': 1,
#          '기능': 1,
#          '블록': 1,
#          '다이어그램': 1,
#          '안전성': 4,
#          '델타': 1,
#          '변조': 1,
#          '용존': 1,
#          '수소': 2,
#          '실시간': 1,
#          '추적': 1,
#          '이': 1,
#          '치환': 1,
#          '타입': 1,
#          '식물': 1,
#          '광유': 2,
#          '개시': 1,
#          '자동차': 1,
#          '전기동차': 1,
#          '계기': 1,
#          '해결': 1,
#          '화생': 1,
#          '물': 1,
#          '연수': 1,
#          '상관관계': 1,
#          '파': 3,
#          '포함': 1,
#          '산정': 1,
#          '습도': 1,
#          '앵글': 1,
#          '프레': 1,
#          '스': 3,
#          '보드': 1,
#          '재단': 1,
#          '단락': 2,
#          '조정': 1,
#          '잔': 1,
#          '여수': 1,
#          '명과': 1,
#          '확률': 1,
#          '파라미터': 1,
#          '지상': 2,
#          '중성': 1,
#          '선': 1,
#          '접지': 2,
#          '탈락': 1,
#          '위험성': 1,
#          '스타일': 1,
#          '방식': 2,
#          '급속': 1,
#          '충전기': 1,
#          '서브': 1,
#          '합성': 1,
#          '전하': 1,
#          '힐': 1,
#          '벨트': 1,
#          '퍼스': 1,
#          '절약': 1,
#          '데이터베이스': 1,
#          '이중': 1,
#          '완전': 1,
#          '퓨리': 1,
#          '면': 2,
#          '불연속': 1,
#          '변': 2,
#          '로부터': 1,
#          '로서': 1,
#          '양자': 1,
#          '화기': 1,
#          '적응': 1,
#          '복사': 1,
#          '세그먼트': 1,
#          '단위': 1,
#          '특징': 1,
#          '강화': 1,
#          '인공': 1,
#          '방어': 1,
#          '개폐': 2,
#          '충격': 2,
#          '보조': 1,
#          '방향성': 2,
#          '결': 2,
#          '합기': 3,
#          '성결': 1,
#          '법': 2,
#          '미조': 2,
#          '정법': 2,
#          '원용': 1,
#          '심': 1,
#          '가변': 1,
#          '디지탈': 1,
#          '힐버트': 1,
#          '이단': 1,
#          '대역폭': 1,
#          '페라이트': 1,
#          '도파관': 1,
#          '위기': 1,
#          '장방형': 1,
#          '등': 1,
#          '책': 1,
#          '트렌스포머': 1,
#          '해무': 1,
#          '의료': 1,
#          '몰핑기법': 1,
#          '진화': 1,
#          '포스트': 1,
#          '휴먼': 1,
#          '위주': 1,
#          '스테이': 1,
#          '징': 1,
#          '사실': 1,
#          '증대': 1,
#          '단일': 1,
#          '이야기': 1,
#          '논리': 1,
#          '현실': 1,
#          '대응': 1,
#          '논문': 1,
#          '폐': 1,
#          '실태': 2,
#          '발전': 1,
#          '소용': 1,
#          '외철': 1,
#          '식물성': 1,
#          '일체': 2,
#          '주상용': 2,
#          '경년': 1,
#          '대표': 1,
#          '전파': 1,
#          '저압': 1,
#          '계력': 1,
#          '증가': 1,
#          '률': 1,
#          '전기철도': 1,
#          '교류': 1,
#          '급전': 1,
#          '코트': 2,
#          '선박': 1,
#          '조직': 1,
#          '침수': 2,
#          '지역': 1,
#          '변전': 2,
#          '설비': 1,
#          '시설': 1,
#          '조사': 1,
#          '차단': 1,
#          '내진': 1,
#          '마찰': 1,
#          '진자': 1,
#          '진장': 1,
#          '치의': 1,
#          '유도전동기': 1,
#          '직입': 1,
#          '동시': 1,
#          '유한요소법': 1,
#          '계산': 1,
#          '주파수': 1,
#          '스펙트럼': 1,
#          '뉴턴랩슨법': 1,
#          '조류': 1,
#          '구속': 1,
#          '제한': 1,
#          '기계': 1,
#          '지하철': 1,
#          '진공': 1,
#          '주형': 1,
#          '확인': 1,
#          '슬림형': 1,
#          '준치': 1})

# %%
word_count = dict()

for tag, counts in count.most_common(80):
    if(len(str(tag))>1):
        word_count[tag] = counts
        print("%s : %d" % (tag, counts))
# Out:
# 트랜스포머 : 192
# 변압기 : 144
# 이용 : 116
# 연구 : 91
# 특성 : 79
# 기반 : 64
# 설계 : 50
# 모델 : 48
# 분석 : 44
# 전류 : 33
# 시스템 : 27
# 효율 : 25
# 적용 : 24
# 컨버터 : 24
# 전력 : 24
# 개발 : 20
# 활용 : 19
# 해석 : 19
# 방법 : 18
# 회로 : 18
# 전압 : 18
# 기법 : 18
# 신호 : 16
# 권선 : 16
# 기적 : 15
# 학습 : 14
# 비교 : 14
# 성능 : 14
# 영향 : 13
# 디자인 : 13
# 절연 : 13
# 사용 : 12
# 구동 : 12
# 예측 : 12
# 임피던스 : 12
# 장치 : 12
# 공진 : 12
# 계통 : 11
# 동작 : 11
# 향상 : 11
# 변환기 : 11
# 대한 : 11
# 냉각 : 11
# 부하 : 11
# 몰드 : 11
# 다중 : 10
# 구조 : 10
# 측정 : 10
# 한국어 : 10
# 진단 : 10
# 출력 : 9
# 전원 : 9
# 초전도 : 9
# 인버터 : 9
# 펄스 : 9
# 평가 : 9
# 압전 : 9
# 알고리즘 : 9
# 발생 : 8
# 모델링 : 8
# 방안 : 8
# 분류 : 8
# 최적 : 8
# 주파 : 8
# 인식 : 8
# 중심 : 8
# 고려 : 8
# 자가 : 8
# 세라믹스 : 8
# 온도 : 8

# %% [markdown]
# ### 히스토그램

# %%
font_path = "/System/Library/Fonts/AppleSDGothicNeo.ttc"
font_name = font_manager.FontProperties(fname = font_path).get_name()
matplotlib.rc('font', family=font_name)

# %%
plt.figure(figsize=(24,5))
plt.xlabel('키워드')
plt.ylabel('빈도수')
plt.grid(True)

sorted_Keys = sorted(word_count, key=word_count.get, reverse=True)
sorted_Values = sorted(word_count.values(), reverse=True)

plt.bar(range(len(word_count)), sorted_Values, align='center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation='75')

plt.show()

# %% [markdown]
# ### 워드클라우드

# %%
# 워드클라우드 생성
wc = WordCloud(font_path, background_color='ivory', width=800, height=600)
cloud=wc.generate_from_frequencies(word_count)

# 시각화
plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
cloud.to_file('transformer_cloud_ko.jpg')
